# %% [markdown]
# Files, exceptional handling, logging and
# memory management Questions

# %%
1. What is the difference between interpreted and compiled languages?

# %% [markdown]
#     Compiled Languages
#
# A compiled language is translated all at once into machine code before the program runs.
#
# Interpreted Languages
#
# An interpreted language is translated line by line while the program is running.

# %% [markdown]
# 2. What is exception handling in Python?
#
#  Exception handling in Python is a way to manage errors gracefully so your program doesn’t crash unexpectedly.
#
# Instead of stopping the program when an error occurs, you can “catch” the error and decide what to do next

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#
#    The finally block in Python is used to run code always, whether an exception occurs or not.
#
# It is commonly used for cleanup tasks like:
#
# closing files
# closing database connections.

# %% [markdown]
# 4.  What is logging in Python?
#
#      Logging in Python is used to record messages about a program’s execution, such as errors, warnings, or information.
#
# It helps in debugging and monitoring programs.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?
#
#       The __del__ method in Python is called automatically when an object is about to be destroyed.
#
# It is used for cleanup tasks like closing files or releasing resources.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
#
# In Python:
#
# import imports the whole module.
# from ... import imports specific functions or variables from a module.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?
#
# In Python, multiple exceptions can be handled using multiple except blocks or a single except block with tuples.

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python?
#
# The with statement in Python is used to handle files safely and automatically close them after use.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#
# The difference is:
#
# Multithreading → multiple threads run within the same process and share memory.
# Multiprocessing → multiple separate processes run independently with separate memory.

# %% [markdown]
# 10. What are the advantages of using logging in a program?
#
# Better tracking of events → records what happens in the program step by step
# Different severity levels → supports DEBUG, INFO, WARNING, ERROR, CRITICAL
# Useful for debugging → helps find and fix issues easily

# %% [markdown]
# 11. What is memory management in Python?
#
# Memory management in Python is the process of automatically handling how memory is allocated, used, and released while a program runs.

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?
#
# try → Write the code that may cause an error
# except → Handle the error if it occurs
# else (optional) → Runs if no error occurs
# finally (optional) → Always runs, used for cleanup.

# %% [markdown]
# 13. Why is memory management important in Python?
#
# Memory management in Python is important because it ensures efficient use of system memory and keeps programs running smoothly.

# %% [markdown]
# 14. What is the role of try and except in exception handling?
#
# try → contains the code that might cause an error
# except → handles the error if it occurs, so the program doesn’t crash.

# %% [markdown]
# 15. How does Python's garbage collection system work?
#
# In Python, garbage collection is the process of automatically removing objects from memory that are no longer needed.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling?
#
# In Python, the else block in exception handling is used to run code only when no error occurs in the try block.
#
# Purpose:
# Executes when try succeeds
# Skips if any exception happen.

# %% [markdown]
# 17. What are the common logging levels in Python?
#
# DEBUG → detailed information for diagnosing problems
# INFO → general information about program execution
# WARNING → something unexpected, but program still works
# ERROR → a serious problem that affects a part of the program.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
# In Python, both os.fork() and multiprocessing are used to create processes, but they work very differently.
#
# os.fork()
# Creates a child process by duplicating the current process
# Available mainly on Unix/Linux systems
# Low-level system call.

# %% [markdown]
# 19. What is the importance of closing a file in Python?
#
# In Python, closing a file is important because it properly releases system resources after file operations are done.
#
# Importance of closing a file:
# Frees system resources → prevents memory/resource leaks
# Saves data safely → ensures all changes are written to disk
# Avoids file corruption → prevents incomplete writes.

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python?
#
# In Python:
#
# file.read() → reads the entire file at once as a single string
# file.readline() → reads one line at a time from the file.

# %% [markdown]
# 21. What is the logging module in Python used for?
#
# In Python, the logging module is used to record messages about a program’s execution, such as events, errors, warnings, and debugging information.
#
# Why it is used:
# Tracks what the program is doing
# Helps in debugging and troubleshooting.

# %% [markdown]
# 22. What is the os module in Python used for in file handling?
#
# In Python, the os module is used in file handling to interact with the operating system and perform operations on files and directories.
#
# Common uses:
# Create files and folders → os.mkdir()
# Delete files → os.remove().

# %% [markdown]
# 23. What are the challenges associated with memory management in Python?
#
# Garbage collection overhead: Python uses reference counting + cyclic garbage collector, which can add performance cost.
# Reference cycles: Objects referencing each other can delay or complicate cleanup.
# Memory leaks: Often caused by lingering references (global variables, caches, closures).
# High memory usage: Python objects have significant overhead compared to low-level languages.

# %% [markdown]
# 24. How do you raise an exception manually in Python?
#
# raise Exception("Something went wrong")

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications?
#
# Multithreading is important because it lets programs do multiple tasks at the same time, improving performance and responsiveness.

# %% [markdown]
# #                            PRATICAL QUESTIONS

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?

# %%
with open("file.txt", "w") as f:
    f.write("Hello World")

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line?

# %%
with open("file.txt", "r") as f:
    for line in f:
        print(line.strip())

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
try:
    with open("file.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file?

# %%
with open("source.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())

# %% [markdown]
# 5.  How would you catch and handle division by zero error in Python?

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %%
try:
    result = 10 / 0
except ZeroDivisionError as e:
    with open("error.log", "a") as log:
        log.write(f"Error: {e}\n")
    print("Error logged")

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.DEBUG,
    format="%(levelname)s:%(message)s"
)

logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling?

# %%
try:
    with open("file.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("Error: File not found")
except Exception as e:
    print("Other error:", e)

# %% [markdown]
# 9.  How can you read a file line by line and store its content in a list in Python?

# %%
with open("file.txt", "r") as f:
    lines = f.readlines()

print(lines)

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %%
with open("file.txt", "a") as f:
    f.write("New line\n")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.

# %%
data = {"name": "Alice"}

try:
    print(data["age"])
except KeyError:
    print("Key does not exist")

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %%
try:
    a = int("abc")   # ValueError
    b = 10 / 0        # ZeroDivisionError

except ValueError:
    print("Invalid value")

except ZeroDivisionError:
    print("Cannot divide by zero")

except Exception as e:
    print("Other error:", e)

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python

# %%
import os

if os.path.exists("file.txt"):
    with open("file.txt", "r") as f:
        print(f.read())
else:
    print("File does not exist")

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages

# %%
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(levelname)s:%(message)s"
)

logging.info("Program started")

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Cannot divide by zero")

logging.info("Program ended")

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
try:
    with open("file.txt", "r") as f:
        content = f.read()
        if not content:
            print("File is empty")
        else:
            print(content)
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

# %%
pip install memory-profiler

# %%
from memory_profiler import profile

@profile
def my_func():
    a = [i for i in range(100000)]
    b = [i * 2 for i in range(100000)]
    return a, b

my_func()

# %% [markdown]
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    for num in numbers:
        f.write(str(num) + "\n")

# %% [markdown]
# 18. numbers = [1, 2, 3, 4, 5]
#
# with open("numbers.txt", "w") as f:
#     for num in numbers:
#         f.write(str(num) + "\n")

# %%
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    f.writelines(f"{n}\n" for n in numbers)

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block.

# %%
try:
    my_list = [1, 2, 3]
    print(my_list[5])          # IndexError

    my_dict = {"a": 1}
    print(my_dict["b"])        # KeyError

except IndexError:
    print("List index out of range")

except KeyError:
    print("Dictionary key not found")

# %% [markdown]
#  20. How would you open a file and read its contents using a context manager in Python.

# %%
with open("file.txt", "r") as f:
    content = f.read()

print(content)
